# %% [markdown]
# ### Intro
#
# Sven works as a Planning Analyst for a city’s Economic Development department. He has been given an **Excel spreadsheet** containing point locations of businesses and needs to load it into an **Esri geodatabase**.

# %% [markdown]
# ### FME Roles
# 1. Authors - create workspaces using FME Desktop and can publish them
# 2. End-users - run workspaces using FME Workbench, FME Server, or an application powered by FME
# 3. FME Server Developers - implement features and services offered by FME Server into other applications
# 4. Administrators - install and maintain the FME platform

# %% [markdown]
# ### Connecting to Data
#
# 1. Type Excel from the Canvas and find the file
# 2. Add coordinates (LL84)
#
# ![image.png](attachment:image.png)
#
# 3. Run
#
# ![image.png](attachment:image-2.png)
#
# 4. Inspect data
#
# ![image.png](attachment:image-3.png)

# %% [markdown]
# ### For Excel files
#
# 1. The dataset is the XLS or XLSX file (a.k.a. the workbook)
# 2. The feature types are the sheets (a.k.a. tables)
# 3. The features are the rows (the columns are the attributes)
